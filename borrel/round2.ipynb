# %% [markdown]
# Copy of play.ipynb to save results from round 1

# %% [markdown]
# Players

# %%
from policies.dummy import Dummy
from policies.do import Do
from policies.ivo import Ivo
from policies.carlos import Carlos
from policies.jakko import Jakko
from policies.mark0 import Mark0
from policies.mark1 import Mark1

from games.minority import Minority
from games.tron import Tron
from games.battleship import Battleship
from games.wonky_rps import WonkyRPS

from itertools import combinations

def get_all_player_classes():
    """
    Here we define all the players that are available to be used in the tournament.
    """
    return [
        Do,
        Ivo,
        Carlos,
        Mark1,
    ]

def init_all_players():
    return [
        player() for player in get_all_player_classes()
    ]

def get_zero_scores(players):
    return {
        player.name: 0
        for player in players
    }

global_scores = get_zero_scores(init_all_players())

def print_ordered_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    ordered_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    print("Scores: " + ", ".join([f"{name}: {score}" for name, score in ordered_scores]))

def print_global_scores():
    ordered_scores = sorted(global_scores.items(), key=lambda item: item[1], reverse=True)
    print("Global scores:")
    for name, score in ordered_scores:
        print(f"{name}: {score}")

def update_global_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    sorted_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    last_score = None
    current_points = len(init_all_players()) - 1
    for name, score in sorted_scores:
        if last_score is not None and last_score != score:
            current_points -= 1
        global_scores[name] += current_points

        last_score = score
    
    print_global_scores()

# %% [markdown]
# ## Minority

# %%
scores = get_zero_scores(init_all_players())

for i in range(21):
    players = init_all_players()

    minority = Minority(players, render=False)

    winners = minority.play_game()

    for winner in winners:
        scores[winner] += 1

    print(minority.get_scores(), f"winner: {winners}")

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'do': 6, 'ivo': 14, 'carlos': 25, 'mark1': 11} winner: ['carlos']
# {'do': 11, 'ivo': 8, 'carlos': 11, 'mark1': 9} winner: ['do', 'carlos']
# {'do': 14, 'ivo': 11, 'carlos': 17, 'mark1': 9} winner: ['carlos']
# {'do': 21, 'ivo': 7, 'carlos': 8, 'mark1': 15} winner: ['do']
# {'do': 8, 'ivo': 16, 'carlos': 18, 'mark1': 11} winner: ['carlos']
# {'do': 17, 'ivo': 11, 'carlos': 11, 'mark1': 18} winner: ['mark1']
# {'do': 12, 'ivo': 14, 'carlos': 11, 'mark1': 11} winner: ['ivo']
# {'do': 11, 'ivo': 8, 'carlos': 18, 'mark1': 14} winner: ['carlos']
# {'do': 10, 'ivo': 10, 'carlos': 12, 'mark1': 16} winner: ['mark1']
# {'do': 9, 'ivo': 12, 'carlos': 14, 'mark1': 14} winner: ['carlos', 'mark1']
# {'do': 10, 'ivo': 12, 'carlos': 8, 'mark1': 7} winner: ['ivo']
# {'do': 15, 'ivo': 11, 'carlos': 11, 'mark1': 12} winner: ['do']
# {'do': 13, 'ivo': 9, 'carlos': 13, 'mark1': 14} winner: ['mark1']
# {'do': 15, 'ivo': 11, 'carlos': 14, 'mark1': 11} winner: ['do']
# {'do': 10, 'ivo': 6, 'carlos': 8, 'mark1': 15} winner: ['mark1']
# {'do': 14, 'ivo': 13, 'carlos': 9, 'mark1': 15} winner: ['mark1']
# {'do': 15, 'ivo': 8, 'carlos': 11, 'mark1': 14} winner: ['do']
# {'do': 12, 'ivo': 10, 'carlos': 16, 'mark1': 11} winner: ['carlos']
# {'do': 13, 'ivo': 20, 'carlos': 12, 'mark1': 15} winner: ['ivo']
# {'do': 10, 'ivo': 14, 'carlos': 11, 'mark1': 22} winner: ['mark1']
# {'do': 15, 'ivo': 13, 'carlos': 8, 'mark1': 9} winner: ['do']
# Scores: carlos: 7, mark1: 7, do: 6, ivo: 3
# Global scores:
# carlos: 3
# mark1: 3
# do: 2
# ivo: 1

# %% [markdown]
# ## Tron

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        tron = Tron([player1, player2], render=False)
        winner = tron.play_game()
        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Scores: carlos: 28, ivo: 16, mark1: 15, do: 7
# Global scores:
# carlos: 6
# mark1: 4
# ivo: 3
# do: 2

# %% [markdown]
# ## Battleship

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()
        
        battleship = Battleship(player1=player1, player2=player2, render=False)
        winner = battleship.play_game()

        print(f"Players: {player1.name} vs {player2.name}, Winner: {winner}")

        if winner == "tie":
            continue
        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs ivo, Winner: ivo
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs carlos, Winner: carlos
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: do vs mark1, Winner: mark1
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: ivo
# Players: ivo vs carlos, Winner: ivo
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs carlos, Winner: tie
# Players: ivo vs carlos, Winner: carlos
# Players: ivo vs mark1, Winner: mark1
# Players: ivo vs mark1, Winner: ivo
# Players: ivo vs mark1, Winner: mark1
# Players: ivo vs mark1, Winner: tie
# Players: ivo vs mark1, Winner: ivo
# Players: ivo vs mark1, Winner: mark1
# Players: ivo vs mark1, Winner: ivo
# Players: ivo vs mark1, Winner: mark1
# Players: ivo vs mark1, Winner: ivo
# Players: ivo vs mark1, Winner: mark1
# Players: ivo vs mark1, Winner: ivo
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: mark1
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: carlos
# Players: carlos vs mark1, Winner: mark1
# Scores: carlos: 28, ivo: 18, mark1: 18, do: 0
# Global scores:
# carlos: 9
# mark1: 6
# ivo: 5
# do: 3

# %% [markdown]
# ## Wonky RPS

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(7):
        player1 = player1_class()
        player2 = player2_class()

        wonky_rps = WonkyRPS(player1, player2, render=False)
        winner = wonky_rps.play_game()

        print(wonky_rps.scores, f", Winner: {winner}")

        if winner == "tie":
            continue
    
        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'do': 33982, 'ivo': 20470} , Winner: do
# {'do': 16713, 'ivo': 14888} , Winner: do
# {'do': 13297, 'ivo': 37255} , Winner: ivo
# {'do': 8833, 'ivo': 23415} , Winner: ivo
# {'do': 17269, 'ivo': 20736} , Winner: ivo
# {'do': 16070, 'ivo': 38043} , Winner: ivo
# {'do': 20330, 'ivo': 15006} , Winner: do
# {'do': 12050, 'carlos': 39927} , Winner: carlos
# {'do': 11264, 'carlos': 63383} , Winner: carlos
# {'do': 10655, 'carlos': 31299} , Winner: carlos
# {'do': 10325, 'carlos': 27190} , Winner: carlos
# {'do': 10900, 'carlos': 44151} , Winner: carlos
# {'do': 12192, 'carlos': 60880} , Winner: carlos
# {'do': 11919, 'carlos': 70297} , Winner: carlos
# {'do': 15968, 'mark1': 38428} , Winner: mark1
# {'do': 23146, 'mark1': 41743} , Winner: mark1
# {'do': 13415, 'mark1': 57986} , Winner: mark1
# {'do': 15047, 'mark1': 72449} , Winner: mark1
# {'do': 10893, 'mark1': 60911} , Winner: mark1
# {'do': 11388, 'mark1': 41074} , Winner: mark1
# {'do': 21895, 'mark1': 44625} , Winner: mark1
# {'ivo': 4956, 'carlos': 26747} , Winner: carlos
# {'ivo': 5349, 'carlos': 40646} , Winner: carlos
# {'ivo': 4522, 'carlos': 55797} , Winner: carlos
# {'ivo': 3923, 'carlos': 18110} , Winner: carlos
# {'ivo': 4905, 'carlos': 10376} , Winner: carlos
# {'ivo': 11665, 'carlos': 24463} , Winner: carlos
# {'ivo': 4768, 'carlos': 30555} , Winner: carlos
# {'ivo': 12157, 'mark1': 41230} , Winner: mark1
# {'ivo': 13904, 'mark1': 28370} , Winner: mark1
# {'ivo': 15613, 'mark1': 48080} , Winner: mark1
# {'ivo': 14918, 'mark1': 33684} , Winner: mark1
# {'ivo': 16301, 'mark1': 42201} , Winner: mark1
# {'ivo': 14742, 'mark1': 13430} , Winner: ivo
# {'ivo': 18751, 'mark1': 41930} , Winner: mark1
# {'carlos': 23024, 'mark1': 6388} , Winner: carlos
# {'carlos': 21791, 'mark1': 8260} , Winner: carlos
# {'carlos': 15797, 'mark1': 6278} , Winner: carlos
# {'carlos': 10822, 'mark1': 7735} , Winner: carlos
# {'carlos': 17580, 'mark1': 7103} , Winner: carlos
# {'carlos': 10494, 'mark1': 11426} , Winner: mark1
# {'carlos': 16559, 'mark1': 13229} , Winner: carlos
# Scores: carlos: 20, mark1: 14, ivo: 5, do: 3
# Global scores:
# carlos: 12
# mark1: 8
# ivo: 6
# do: 3

# %%
print_global_scores()

# %% [markdown]
# Scores from round 1:
#
# mark1: 11
# do: 6
# carlos: 5
# ivo: 4
#
# Scores from round 2:
#
# Global scores:
# carlos: 12
# mark1: 8
# ivo: 6
# do: 3
#
# After round 2, the scores are:
#
# mark1: 19
# carlos: 17
# ivo: 10
# do: 9
