# %% [markdown]
# Just run all cells :)

# %% [markdown]
# Players

# %%
from borrel.policies.dummy import Dummy
from borrel.policies.ivo import Ivo
from borrel.policies.jakko import Jakko
from borrel.policies.mark import Mark
from borrel.policies.allia import Allia
from borrel.policies.dominique import Dominique
from borrel.policies.dirk import Dirk
from borrel.policies.mees import Mees

from borrel.games.tron import Tron
from borrel.games.sorry import Sorry
from borrel.games.dots_and_lines import DotsAndLines
from borrel.games.rps_gun import RPS_Gun

from itertools import combinations

def get_all_player_classes():
    """
    Here we define all the players that are available to be used in the tournament.
    """
    return [
        Jakko,
        Ivo,
        Mark,
        Allia,
        Dominique,
        Dirk,
        Mees,
    ]

def init_all_players():
    return [
        player() for player in get_all_player_classes()
    ]

def get_zero_scores(players):
    return {
        player.name: 0
        for player in players
    }

global_scores = get_zero_scores(init_all_players())

def print_ordered_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    ordered_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    print("Scores: " + ", ".join([f"{name}: {score}" for name, score in ordered_scores]))

def print_global_scores():
    ordered_scores = sorted(global_scores.items(), key=lambda item: item[1], reverse=True)
    print("Global scores:")
    for name, score in ordered_scores:
        print(f"{name}: {score}")

def update_global_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    sorted_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    last_score = None
    current_points = len(init_all_players()) - 1
    for name, score in sorted_scores:
        if last_score is not None and last_score != score:
            current_points -= 1
        global_scores[name] += current_points

        last_score = score

    print_global_scores()

# %% [markdown]
# ## Tron

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        tron = Tron([player1, player2], render=False)
        winner = tron.play_game()
        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Scores: allia: 26, dirk: 26, ivo: 23, jakko: 18, mees: 18, mark: 17, dominique: 15
# Global scores:
# allia: 6
# dirk: 6
# ivo: 5
# jakko: 4
# mees: 4
# mark: 3
# dominique: 2

# %% [markdown]
# ## Sorry

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for i in range(11):
    sorry = Sorry(players=[player() for player in player_classes], render=False)
    winners = sorry.play_game()

    print(f"Winner(s): {winners}")

    for winner in winners:
         scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Winner(s): ['mark']
# Winner(s): ['jakko']
# Winner(s): ['ivo']
# Winner(s): ['mees']
# Winner(s): ['dominique']
# Winner(s): ['ivo']
# Winner(s): ['mark']
# Winner(s): ['ivo']
# Winner(s): ['mees']
# Winner(s): ['mark']
# Winner(s): ['jakko']
# Scores: ivo: 3, mark: 3, jakko: 2, mees: 2, dominique: 1, allia: 0, dirk: 0
# Global scores:
# ivo: 11
# jakko: 9
# mark: 9
# allia: 9
# dirk: 9
# mees: 9
# dominique: 6

# %% [markdown]
# ## Dots and Lines

# %% [markdown]
# ## Rock Paper Scissors Gun Duck

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(7):
        player1 = player1_class()
        player2 = player2_class()

        rps_gun = RPS_Gun(player1, player2, render=False)
        winner = rps_gun.play_game()

        print(rps_gun.scores, f", Winner: {winner}")

        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'jakko': 18100, 'ivo': 17101} , Winner: jakko
# {'jakko': 16314, 'ivo': 15500} , Winner: jakko
# {'jakko': -2309266926397989395, 'ivo': 68300} , Winner: ivo
# {'jakko': 14506, 'ivo': 16975} , Winner: ivo
# {'jakko': 13287, 'ivo': 19789} , Winner: ivo
# {'jakko': 10763, 'ivo': 23400} , Winner: ivo
# {'jakko': -8837192477205186261, 'ivo': 72200} , Winner: ivo
# {'jakko': 16900, 'mark': 16833} , Winner: jakko
# {'jakko': 17700, 'mark': 15510} , Winner: jakko
# {'jakko': 19658, 'mark': 12600} , Winner: jakko
# {'jakko': 12639, 'mark': 20500} , Winner: mark
# {'jakko': 16424, 'mark': 17500} , Winner: mark
# {'jakko': 17566, 'mark': 15200} , Winner: jakko
# {'jakko': 14233, 'mark': 19800} , Winner: mark
# {'jakko': 18328, 'allia': 14900} , Winner: jakko
# {'jakko': 16500, 'allia': 14877} , Winner: jakko
# {'jakko': 15863, 'allia': 16728} , Winner: allia
# {'jakko': 70400, 'allia': -9351596205935078333} , Winner: jakko
# {'jakko': 70900, 'allia': -14653527985966419555} , Winner: jakko
# {'jakko': 15266, 'allia': 17689} , Winner: allia
# {'jakko': 16200, 'allia': 16295} , Winner: allia
# {'jakko': 15700, 'dominique': 16866} , Winner: dominique
# {'jakko': 15800, 'dominique': 16851} , Winner: dominique
# {'jakko': 19600, 'dominique': 13596} , Winner: jakko
# {'jakko': 16266, 'dominique': 17141} , Winner: dominique
# {'jakko': 18300, 'dominique': 16189} , Winner: jakko
# {'jakko': 14783, 'dominique': 17300} , Winner: dominique
# {'jakko': 17100, 'dominique': 15506} , Winner: jakko
# {'jakko': 14200, 'dirk': 18988} , Winner: dirk
# {'jakko': 16356, 'dirk': 16600} , Winner: dirk
# {'jakko': 15200, 'dirk': 17013} , Winner: dirk
# {'jakko': 69300, 'dirk': -9512102624035596568} , Winner: jakko
# {'jakko': 16352, 'dirk': 16690} , Winner: dirk
# {'jakko': 18600, 'dirk': 14989} , Winner: jakko
# {'jakko': -1573829272593213074, 'dirk': 68441} , Winner: dirk
# {'jakko': 14212, 'mees': 19300} , Winner: mees
# {'jakko': 17693, 'mees': 15100} , Winner: jakko
# {'jakko': -8247486071850703699, 'mees': 70400} , Winner: mees
# {'jakko': -20644223787320654931, 'mees': 69700} , Winner: mees
# {'jakko': 20800, 'mees': 10897} , Winner: jakko
# {'jakko': -25095052297441761554, 'mees': 73000} , Winner: mees
# {'jakko': 68400, 'mees': -833412657775614938} , Winner: jakko
# {'ivo': 13573, 'mark': 19100} , Winner: mark
# {'ivo': 18161, 'mark': 12790} , Winner: ivo
# {'ivo': -9279322831260538149, 'mark': 71500} , Winner: mark
# {'ivo': 69990, 'mark': -6241208658703743180} , Winner: ivo
# {'ivo': 69000, 'mark': -2144007620285045735} , Winner: ivo
# {'ivo': 15590, 'mark': 17050} , Winner: mark
# {'ivo': 16390, 'mark': 16564} , Winner: mark
# {'ivo': 15890, 'allia': 17400} , Winner: allia
# {'ivo': 69000, 'allia': -6842481167321712387} , Winner: ivo
# {'ivo': 15466, 'allia': 16300} , Winner: allia
# {'ivo': 15647, 'allia': 16979} , Winner: allia
# {'ivo': 18200, 'allia': 14154} , Winner: ivo
# {'ivo': 21900, 'allia': 11386} , Winner: ivo
# {'ivo': 8956, 'allia': 24400} , Winner: allia
# {'ivo': 68700, 'dominique': -3174309412891717425} , Winner: ivo
# {'ivo': 16290, 'dominique': 17788} , Winner: dominique
# {'ivo': 15841, 'dominique': 16790} , Winner: dominique
# {'ivo': 14060, 'dominique': 19500} , Winner: dominique
# {'ivo': 18900, 'dominique': 14041} , Winner: ivo
# {'ivo': 18300, 'dominique': 14352} , Winner: ivo
# {'ivo': 13200, 'dominique': 19177} , Winner: dominique
# {'ivo': 17977, 'dirk': 15000} , Winner: ivo
# {'ivo': 16067, 'dirk': 16979} , Winner: dirk
# {'ivo': 16760, 'dirk': 16779} , Winner: dirk
# {'ivo': 21600, 'dirk': 11666} , Winner: ivo
# {'ivo': 10790, 'dirk': 22439} , Winner: dirk
# {'ivo': 17088, 'dirk': 16200} , Winner: ivo
# {'ivo': 17100, 'dirk': 16783} , Winner: ivo
# {'ivo': 20689, 'mees': 13500} , Winner: ivo
# {'ivo': 69200, 'mees': -7461819912146766991} , Winner: ivo
# {'ivo': 12489, 'mees': 21600} , Winner: mees
# {'ivo': 18577, 'mees': 14090} , Winner: ivo
# {'ivo': 14200, 'mees': 18323} , Winner: mees
# {'ivo': -6393845860193292005, 'mees': 69800} , Winner: mees
# {'ivo': 16287, 'mees': 18390} , Winner: mees
# {'mark': 17444, 'allia': 15700} , Winner: mark
# {'mark': -15761593989119041521, 'allia': 72400} , Winner: allia
# {'mark': 71500, 'allia': -14894462922664623609} , Winner: mark
# {'mark': 14506, 'allia': 18490} , Winner: allia
# {'mark': 18400, 'allia': 14430} , Winner: mark
# {'mark': 13989, 'allia': 19100} , Winner: allia
# {'mark': 16838, 'allia': 16090} , Winner: mark
# {'mark': 18976, 'dominique': 14800} , Winner: mark
# {'mark': 15200, 'dominique': 17289} , Winner: dominique
# {'mark': 16800, 'dominique': 15866} , Winner: mark
# {'mark': 18600, 'dominique': 14677} , Winner: mark
# {'mark': -9210109309096834078, 'dominique': 72000} , Winner: dominique
# {'mark': 18739, 'dominique': 14000} , Winner: mark
# {'mark': 14900, 'dominique': 17576} , Winner: dominique
# {'mark': 18476, 'dirk': 13400} , Winner: mark
# {'mark': 18190, 'dirk': 14889} , Winner: mark
# {'mark': -5232254116553810064, 'dirk': 68200} , Winner: dirk
# {'mark': 14600, 'dirk': 19087} , Winner: dirk
# {'mark': 14838, 'dirk': 18500} , Winner: dirk
# {'mark': 17200, 'dirk': 15090} , Winner: mark
# {'mark': 17590, 'dirk': 15466} , Winner: mark
# {'mark': 20878, 'mees': 12458} , Winner: mark
# {'mark': 70000, 'mees': -10078615324494962044} , Winner: mark
# {'mark': 14140, 'mees': 19000} , Winner: mees
# {'mark': 15800, 'mees': 16974} , Winner: mees
# {'mark': 17733, 'mees': 14879} , Winner: mark
# {'mark': 15563, 'mees': 17551} , Winner: mees
# {'mark': 17967, 'mees': 15800} , Winner: mark
# {'allia': 14590, 'dominique': 18741} , Winner: dominique
# {'allia': 15601, 'dominique': 16000} , Winner: dominique
# {'allia': 18741, 'dominique': 15500} , Winner: allia
# {'allia': 17000, 'dominique': 16301} , Winner: allia
# {'allia': -3905156810508813625, 'dominique': 68500} , Winner: dominique
# {'allia': 19200, 'dominique': 14064} , Winner: allia
# {'allia': 70600, 'dominique': -14250769332343511130} , Winner: allia
# {'allia': 16863, 'dirk': 14790} , Winner: allia
# {'allia': 71390, 'dirk': -10576219638103587164} , Winner: allia
# {'allia': 19560, 'dirk': 12800} , Winner: allia
# {'allia': 23466, 'dirk': 10563} , Winner: allia
# {'allia': 15200, 'dirk': 18763} , Winner: dirk
# {'allia': 15390, 'dirk': 18916} , Winner: dirk
# {'allia': 21038, 'dirk': 13090} , Winner: allia
# {'allia': 12300, 'mees': 18749} , Winner: mees
# {'allia': -8175601070969525980, 'mees': 70300} , Winner: mees
# {'allia': 20590, 'mees': 13320} , Winner: allia
# {'allia': 69400, 'mees': -6249763319586248100} , Winner: allia
# {'allia': 19053, 'mees': 13974} , Winner: allia
# {'allia': 72290, 'mees': -11789896728856957984} , Winner: allia
# {'allia': -4587310024173252745, 'mees': 68067} , Winner: mees
# {'dominique': 15653, 'dirk': 14300} , Winner: dominique
# {'dominique': 67500, 'dirk': -1659502492672861809} , Winner: dominique
# {'dominique': 17500, 'dirk': 15350} , Winner: dominique
# {'dominique': 12656, 'dirk': 20200} , Winner: dirk
# {'dominique': 15990, 'dirk': 17078} , Winner: dirk
# {'dominique': 17022, 'dirk': 15726} , Winner: dominique
# {'dominique': 19990, 'dirk': 13605} , Winner: dominique
# {'dominique': 12533, 'mees': 19800} , Winner: mees
# {'dominique': 68690, 'mees': -10912325246635095640} , Winner: dominique
# {'dominique': 72000, 'mees': -18255526815988994182} , Winner: dominique
# {'dominique': 15000, 'mees': 17678} , Winner: mees
# {'dominique': 17100, 'mees': 16149} , Winner: dominique
# {'dominique': 16300, 'mees': 15286} , Winner: dominique
# {'dominique': 20290, 'mees': 11888} , Winner: dominique
# {'dirk': 15266, 'mees': 16190} , Winner: mees
# {'dirk': 15970, 'mees': 16100} , Winner: mees
# {'dirk': 16000, 'mees': 16890} , Winner: mees
# {'dirk': 17596, 'mees': 14320} , Winner: dirk
# {'dirk': 13443, 'mees': 20300} , Winner: mees
# {'dirk': 19400, 'mees': 13366} , Winner: dirk
# {'dirk': 68600, 'mees': -1911134943556155422} , Winner: dirk
# Scores: dominique: 24, mark: 23, allia: 23, ivo: 21, mees: 20, jakko: 18, dirk: 18
# Global scores:
# ivo: 15
# mark: 14
# allia: 14
# dominique: 12
# mees: 12
# jakko: 11
# dirk: 11

# %%
print_global_scores()
# Out:
# Global scores:
# ivo: 15
# mark: 14
# allia: 14
# dominique: 12
# mees: 12
# jakko: 11
# dirk: 11
