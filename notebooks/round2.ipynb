# %% [markdown]
# Just run all cells :)

# %% [markdown]
# Players

# %%
from borrel.policies.dummy import Dummy
from borrel.policies.ivo import Ivo
from borrel.policies.jakko import Jakko
from borrel.policies.mark import Mark
from borrel.policies.allia import Allia
from borrel.policies.dominique import Dominique
from borrel.policies.dirk import Dirk
from borrel.policies.mees import Mees
from borrel.policies.daniel import Daniel

from borrel.games.tron import Tron
from borrel.games.sorry import Sorry
from borrel.games.dots_and_lines import DotsAndLines
from borrel.games.rps_gun import RPS_Gun

from itertools import combinations

def get_all_player_classes():
    """
    Here we define all the players that are available to be used in the tournament.
    """
    return [
        Ivo,
        Mark,
        Dominique,
        Dirk,
        Mees,
        Daniel,
    ]

def init_all_players():
    return [
        player() for player in get_all_player_classes()
    ]

def get_zero_scores(players):
    return {
        player.name: 0
        for player in players
    }

global_scores = get_zero_scores(init_all_players())

def print_ordered_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    ordered_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    print("Scores: " + ", ".join([f"{name}: {score}" for name, score in ordered_scores]))

def print_global_scores():
    ordered_scores = sorted(global_scores.items(), key=lambda item: item[1], reverse=True)
    print("Global scores:")
    for name, score in ordered_scores:
        print(f"{name}: {score}")

def update_global_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    sorted_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    last_score = None
    current_points = len(init_all_players()) - 1
    for name, score in sorted_scores:
        if last_score is not None and last_score != score:
            current_points -= 1
        global_scores[name] += current_points

        last_score = score

    print_global_scores()

# %% [markdown]
# ## Tron

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        tron = Tron([player1, player2], render=False)
        winner = tron.play_game()
        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Scores: dominique: 22, daniel: 20, mark: 10, mees: 9, ivo: 8, dirk: 0
# Global scores:
# dominique: 5
# daniel: 4
# mark: 3
# mees: 2
# ivo: 1
# dirk: 0

# %% [markdown]
# ## Sorry

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for i in range(11):
    sorry = Sorry(players=[player() for player in player_classes], render=False)
    winners = sorry.play_game()

    print(f"Winner(s): {winners}")

    for winner in winners:
         scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Winner(s): ['dominique']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 7
#       5 for i in range(11):
#       6     sorry = Sorry(players=[player() for player in player_classes], render=False)
# ----> 7     winners = sorry.play_game()
#       9     print(f"Winner(s): {winners}")
#      11     for winner in winners:
#
# File ~/git/Games_Borrel/borrel/games/sorry.py:138, in Sorry.play_game(self)
#     135 self.reset()
#     137 while True:
# --> 138     self.play_turn()
#     139     for player in self.players:
#     140         if len(self.info["pieces_finished"][player.name]) == 4:
#
# File ~/git/Games_Borrel/borrel/games/sorry.py:71, in Sorry.play_turn(self)
#      68 if self.render:
#      69     self.render_state(dice_roll, player.name)
# ---> 71 move = player.sorry(
#      72     copy.deepcopy(self.board), copy.deepcopy(self.info), dice_roll
#      73 )
#      75 if self.render:
#      76     print(f"{player.name} decides to move piece {move}")
#
# File ~/git/Games_Borrel/borrel/policies/mees.py:505, in Mees.sorry(self, board, info, dice_roll)
#     502 finished = info["pieces_finished"][self.name]
#     503 start_pos = (home_idx + 1) % board_length
# --> 505 my_on_board = {
#     506     int(str(board.loc[i, "space"]).split("_")[-1]): i
#     507     for i in board.index
#     508     if board.loc[i, "space"] is not None
#     509     and str(board.loc[i, "space"]).startswith(self.name + "_")
#     510 }
#     512 opp_home_map = {
#     513     p: board[board["home"] == p].index[0]
#     514     for p in info["pieces_at_home"].keys()
#     515     if p != self.name
#     516 }
#     518 def dist_to_home(player_home_idx, pos):
#
# File ~/git/Games_Borrel/borrel/policies/mees.py:508, in <dictcomp>(.0)
#     502 finished = info["pieces_finished"][self.name]
#     503 start_pos = (home_idx + 1) % board_length
#     505 my_on_board = {
#     506     int(str(board.loc[i, "space"]).split("_")[-1]): i
#     507     for i in board.index
# --> 508     if board.loc[i, "space"] is not None
#     509     and str(board.loc[i, "space"]).startswith(self.name + "_")
#     510 }
#     512 opp_home_map = {
#     513     p: board[board["home"] == p].index[0]
#     514     for p in info["pieces_at_home"].keys()
#     515     if p != self.name
#     516 }
#     518 def dist_to_home(player_home_idx, pos):
#
# File ~/.cache/pypoetry/virtualenvs/borrel-m64kQQH--py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:1178, in _LocationIndexer.__getitem__(self, key)
#    1176 @final
#    1177 def __getitem__(self, key):
# -> 1178     check_dict_or_set_indexers(key)
#    1179     if type(key) is tuple:
#    1180         key = tuple(list(x) if is_iterator(x) else x for x in key)
#
# File ~/.cache/pypoetry/virtualenvs/borrel-m64kQQH--py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:2772, in check_dict_or_set_indexers(key)
#    2765 def check_dict_or_set_indexers(key) -> None:
#    2766     """
#    2767     Check if the indexer is or contains a dict or set, which is no longer allowed.
#    2768     """
#    2769     if (
#    2770         isinstance(key, set)
#    2771         or isinstance(key, tuple)
# -> 2772         and any(isinstance(x, set) for x in key)
#    2773     ):
#    2774         raise TypeError(
#    2775             "Passing a set as an indexer is not supported. Use a list instead."
#    2776         )
#    2778     if (
#    2779         isinstance(key, dict)
#    2780         or isinstance(key, tuple)
#    2781         and any(isinstance(x, dict) for x in key)
#    2782     ):
#
# File ~/.cache/pypoetry/virtualenvs/borrel-m64kQQH--py3.11/lib/python3.11/site-packages/pandas/core/indexing.py:2772, in <genexpr>(.0)
#    2765 def check_dict_or_set_indexers(key) -> None:
#    2766     """
#    2767     Check if the indexer is or contains a dict or set, which is no longer allowed.
#    2768     """
#    2769     if (
#    2770         isinstance(key, set)
#    2771         or isinstance(key, tuple)
# -> 2772         and any(isinstance(x, set) for x in key)
#    2773     ):
#    2774         raise TypeError(
#    2775             "Passing a set as an indexer is not supported. Use a list instead."
#    2776         )
#    2778     if (
#    2779         isinstance(key, dict)
#    2780         or isinstance(key, tuple)
#    2781         and any(isinstance(x, dict) for x in key)
#    2782     ):
#
# KeyboardInterrupt:

# %% [markdown]
# ## Dots and Lines

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        dots_and_lines = DotsAndLines(player1, player2, size=5, render=False)
        winner = dots_and_lines.play_game()

        print(dots_and_lines.scores, f", Winner: {winner}")

        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo': 24, 'mark': 1} , Winner: ivo
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo': 23, 'mark': 2} , Winner: ivo
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo': 24, 'mark': 1} , Winner: ivo
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo': 25, 'mark': 0} , Winner: ivo
# {'ivo':
# {'mees': 25, 'daniel': 0} , Winner: mees
# {'mees': 24, 'daniel': 1} , Winner: mees
# {'mees': 24, 'daniel': 1} , Winner: mees
# {'mees': 23, 'daniel': 2} , Winner: mees
# {'mees': 22, 'daniel': 3} , Winner: mees
# {'mees': 25, 'daniel': 0} , Winner: mees
# {'mees': 23, 'daniel': 2} , Winner: mees
# {'mees': 24, 'daniel': 1} , Winner: mees
# {'mees': 25, 'daniel': 0} , Winner: mees
# {'mees': 25, 'daniel': 0} , Winner: mees
# Scores: ivo: 48, mees: 45, dominique: 39, dirk: 14, mark: 10, daniel: 9
# Global scores:
# dominique: 8
# ivo: 6
# mees: 6
# mark: 4
# daniel: 4
# dirk: 2

# %% [markdown]
# ## Rock Paper Scissors Gun Duck

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(5):
        player1 = player1_class()
        player2 = player2_class()

        rps_gun = RPS_Gun(player1, player2, render=False)
        winner = rps_gun.play_game()

        print(rps_gun.scores, f", Winner: {winner}")

        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'ivo': 84859, 'mark': -18480028670299522948} , Winner: ivo
# {'ivo': 84689, 'mark': -9741270556558846974} , Winner: ivo
# {'ivo': 86675, 'mark': -56967651525711873406} , Winner: ivo
# {'ivo': 85077, 'mark': -25859365415149263001} , Winner: ivo
# {'ivo': 28600, 'mark': 48} , Winner: ivo
# {'ivo': 74228, 'dominique': -7747679104076683} , Winner: ivo
# {'ivo': 75125, 'dominique': -44077614806972478} , Winner: ivo
# {'ivo': 84477, 'dominique': -5567853993552064971} , Winner: ivo
# {'ivo': 86800, 'dominique': -12704036706892088217} , Winner: ivo
# {'ivo': 73300, 'dominique': -10633679057617610} , Winner: ivo
# {'ivo': 21619, 'dirk': 15900} , Winner: ivo
# {'ivo': 18773, 'dirk': 16200} , Winner: ivo
# {'ivo': 12588, 'dirk': 18700} , Winner: dirk
# {'ivo': 20745, 'dirk': 15900} , Winner: ivo
# {'ivo': 20000, 'dirk': 16400} , Winner: ivo
# {'ivo': 1050, 'mees': 638616} , Winner: mees
# {'ivo': 8845, 'mees': 1200147} , Winner: mees
# {'ivo': 2661, 'mees': 1154570} , Winner: mees
# {'ivo': 3738, 'mees': 5414829} , Winner: mees
# {'ivo': 4740, 'mees': 1521986} , Winner: mees
# {'ivo': 27569, 'daniel': 11400} , Winner: ivo
# {'ivo': 85177, 'daniel': -6461407330983189559} , Winner: ivo
# {'ivo': 26859, 'daniel': 11100} , Winner: ivo
# {'ivo': 30794, 'daniel': 7700} , Winner: ivo
# {'ivo': 71834, 'daniel': -413025164211305} , Winner: ivo
# {'mark': 17100, 'dominique': 186987} , Winner: dominique
# {'mark': 14290, 'dominique': 86569} , Winner: dominique
# {'mark': 21590, 'dominique': 51362} , Winner: dominique
# {'mark': 16900, 'dominique': 47958} , Winner: dominique
# {'mark': 13200, 'dominique': 95676} , Winner: dominique
# {'mark': 14400, 'dirk': 16400} , Winner: dirk
