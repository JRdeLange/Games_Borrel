# %% [markdown]
# Just run all cells :)

# %% [markdown]
# Players

# %%
from borrel.policies.dummy import Dummy
from borrel.policies.ivo import Ivo
from borrel.policies.jakko import Jakko
from borrel.policies.mark import Mark
from borrel.policies.allia import Allia
from borrel.policies.dominique import Dominique
from borrel.policies.dirk import Dirk
from borrel.policies.mees import Mees
from borrel.policies.daniel import Daniel

from borrel.games.tron import Tron
from borrel.games.sorry import Sorry
from borrel.games.dots_and_lines import DotsAndLines
from borrel.games.rps_gun import RPS_Gun
from borrel.games.minority import Minority

from itertools import combinations

def get_all_player_classes():
    """
    Here we define all the players that are available to be used in the tournament.
    """
    return [
        Ivo,
        Mark,
        Dominique,
        Mees,
        Daniel,
    ]

def init_all_players():
    return [
        player() for player in get_all_player_classes()
    ]

def get_zero_scores(players):
    return {
        player.name: 0
        for player in players
    }

global_scores = get_zero_scores(init_all_players())

def print_ordered_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    ordered_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    print("Scores: " + ", ".join([f"{name}: {score}" for name, score in ordered_scores]))

def print_global_scores():
    ordered_scores = sorted(global_scores.items(), key=lambda item: item[1], reverse=True)
    print("Global scores:")
    for name, score in ordered_scores:
        print(f"{name}: {score}")

def update_global_scores(scores: dict[str, int]):
    """
    Ranks the scores dict by score
    """
    sorted_scores = sorted(scores.items(), key=lambda item: item[1], reverse=True)
    last_score = None
    current_points = len(init_all_players()) - 1
    for name, score in sorted_scores:
        if last_score is not None and last_score != score:
            current_points -= 1
        global_scores[name] += current_points

        last_score = score

    print_global_scores()

# %% [markdown]
# ## Tron

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        tron = Tron([player1, player2], render=False)
        winner = tron.play_game()
        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# Scores: mees: 26, dominique: 16, daniel: 16, ivo: 6, mark: 1
# Global scores:
# mees: 4
# dominique: 3
# daniel: 3
# ivo: 2
# mark: 1

# %% [markdown]
# ## Minority

# %%
scores = get_zero_scores(init_all_players())

for i in range(21):
    players = init_all_players()

    minority = Minority(players, render=False)

    winners = minority.play_game()

    for winner in winners:
        scores[winner] += 1

    print(minority.get_scores(), f"winner: {winners}")

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'ivo': 50, 'mark': 45, 'dominique': 5, 'mees': 34, 'daniel': 7} winner: ['ivo']
# {'ivo': 53, 'mark': 45, 'dominique': 6, 'mees': 32, 'daniel': 4} winner: ['ivo']
# {'ivo': 52, 'mark': 46, 'dominique': 8, 'mees': 26, 'daniel': 9} winner: ['ivo']
# {'ivo': 50, 'mark': 47, 'dominique': 5, 'mees': 27, 'daniel': 6} winner: ['ivo']
# {'ivo': 49, 'mark': 32, 'dominique': 7, 'mees': 37, 'daniel': 6} winner: ['ivo']
# {'ivo': 50, 'mark': 57, 'dominique': 6, 'mees': 28, 'daniel': 6} winner: ['mark']
# {'ivo': 49, 'mark': 30, 'dominique': 12, 'mees': 29, 'daniel': 12} winner: ['ivo']
# {'ivo': 50, 'mark': 45, 'dominique': 12, 'mees': 31, 'daniel': 12} winner: ['ivo']
# {'ivo': 53, 'mark': 34, 'dominique': 10, 'mees': 33, 'daniel': 11} winner: ['ivo']
# {'ivo': 52, 'mark': 37, 'dominique': 11, 'mees': 31, 'daniel': 11} winner: ['ivo']
# {'ivo': 52, 'mark': 45, 'dominique': 9, 'mees': 24, 'daniel': 11} winner: ['ivo']
# {'ivo': 45, 'mark': 38, 'dominique': 15, 'mees': 27, 'daniel': 15} winner: ['ivo']
# {'ivo': 52, 'mark': 45, 'dominique': 10, 'mees': 31, 'daniel': 8} winner: ['ivo']
# {'ivo': 52, 'mark': 42, 'dominique': 7, 'mees': 32, 'daniel': 7} winner: ['ivo']
# {'ivo': 54, 'mark': 37, 'dominique': 3, 'mees': 34, 'daniel': 4} winner: ['ivo']
# {'ivo': 54, 'mark': 49, 'dominique': 6, 'mees': 23, 'daniel': 4} winner: ['ivo']
# {'ivo': 52, 'mark': 45, 'dominique': 5, 'mees': 30, 'daniel': 4} winner: ['ivo']
# {'ivo': 53, 'mark': 44, 'dominique': 8, 'mees': 23, 'daniel': 8} winner: ['ivo']
# {'ivo': 48, 'mark': 35, 'dominique': 13, 'mees': 26, 'daniel': 13} winner: ['ivo']
# {'ivo': 49, 'mark': 48, 'dominique': 8, 'mees': 33, 'daniel': 8} winner: ['ivo']
# {'ivo': 50, 'mark': 43, 'dominique': 11, 'mees': 25, 'daniel': 12} winner: ['ivo']
# Scores: ivo: 20, mark: 1, dominique: 0, mees: 0, daniel: 0
# Global scores:
# ivo: 6
# mees: 6
# dominique: 5
# daniel: 5
# mark: 4

# %% [markdown]
# ## Dots and Lines

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(11):
        player1 = player1_class()
        player2 = player2_class()

        dots_and_lines = DotsAndLines(player1, player2, size=5, render=False)
        winner = dots_and_lines.play_game()

        print(dots_and_lines.scores, f", Winner: {winner}")

        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'ivo': 13, 'mark': 12} , Winner: ivo
# {'ivo': 11, 'mark': 14} , Winner: mark
# {'ivo': 12, 'mark': 13} , Winner: mark
# {'ivo': 6, 'mark': 19} , Winner: mark
# {'ivo': 8, 'mark': 17} , Winner: mark
# {'ivo': 11, 'mark': 14} , Winner: mark
# {'ivo': 9, 'mark': 16} , Winner: mark
# {'ivo': 14, 'mark': 11} , Winner: ivo
# {'ivo': 10, 'mark': 15} , Winner: mark
# {'ivo': 10, 'mark': 15} , Winner: mark
# {'ivo': 10, 'mark': 15} , Winner: mark
# {'ivo': 19, 'dominique': 6} , Winner: ivo
# {'ivo': 11, 'dominique': 14} , Winner: dominique
# {'ivo': 16, 'dominique': 9} , Winner: ivo
# {'ivo': 20, 'dominique': 5} , Winner: ivo
# {'ivo': 21, 'dominique': 4} , Winner: ivo
# {'ivo': 20, 'dominique': 5} , Winner: ivo
# {'ivo': 21, 'dominique': 4} , Winner: ivo
# {'ivo': 15, 'dominique': 10} , Winner: ivo
# {'ivo': 18, 'dominique': 7} , Winner: ivo
# {'ivo': 18, 'dominique': 7} , Winner: ivo
# {'ivo': 14, 'dominique': 11} , Winner: ivo
# {'ivo': 14, 'mees': 11} , Winner: ivo
# {'ivo': 23, 'mees': 2} , Winner: ivo
# {'ivo': 16, 'mees': 9} , Winner: ivo
# {'ivo': 14, 'mees': 11} , Winner: ivo
# {'ivo': 16, 'mees': 9} , Winner: ivo
# {'ivo': 9, 'mees': 16} , Winner: mees
# {'ivo': 7, 'mees': 18} , Winner: mees
# {'ivo': 14, 'mees': 11} , Winner: ivo
# {'ivo': 15, 'mees': 10} , Winner: ivo
# {'ivo': 10, 'mees': 15} , Winner: mees
# {'ivo': 17, 'mees': 8} , Winner: ivo
# {'ivo': 9, 'daniel': 16} , Winner: daniel
# {'ivo': 6, 'daniel': 19} , Winner: daniel
# {'ivo': 15, 'daniel': 10} , Winner: ivo
# {'ivo': 9, 'daniel': 16} , Winner: daniel
# {'ivo': 19, 'daniel': 6} , Winner: ivo
# {'ivo': 12, 'daniel': 13} , Winner: daniel
# {'ivo': 14, 'daniel': 11} , Winner: ivo
# {'ivo': 17, 'daniel': 8} , Winner: ivo
# {'ivo': 18, 'daniel': 7} , Winner: ivo
# {'ivo': 8, 'daniel': 17} , Winner: daniel
# {'ivo': 19, 'daniel': 6} , Winner: ivo
# {'mark': 24, 'dominique': 1} , Winner: mark
# {'mark': 15, 'dominique': 10} , Winner: mark
# {'mark': 25, 'dominique': 0} , Winner: mark
# {'mark': 18, 'dominique': 7} , Winner: mark
# {'mark': 25, 'dominique': 0} , Winner: mark
# {'mark': 18, 'dominique': 7} , Winner: mark
# {'mark': 25, 'dominique': 0} , Winner: mark
# {'mark': 20, 'dominique': 5} , Winner: mark
# {'mark': 21, 'dominique': 4} , Winner: mark
# {'mark': 25, 'dominique': 0} , Winner: mark
# {'mark': 19, 'dominique': 6} , Winner: mark
# {'mark': 17, 'mees': 8} , Winner: mark
# {'mark': 17, 'mees': 8} , Winner: mark
# {'mark': 16, 'mees': 9} , Winner: mark
# {'mark': 19, 'mees': 6} , Winner: mark
# {'mark': 19, 'mees': 6} , Winner: mark
# {'mark': 15, 'mees': 10} , Winner: mark
# {'mark': 17, 'mees': 8} , Winner: mark
# {'mark': 25, 'mees': 0} , Winner: mark
# {'mark': 15, 'mees': 10} , Winner: mark
# {'mark': 21, 'mees': 4} , Winner: mark
# {'mark': 13, 'mees': 12} , Winner: mark
# {'mark': 13, 'daniel': 12} , Winner: mark
# {'mark': 15, 'daniel': 10} , Winner: mark
# {'mark': 12, 'daniel': 13} , Winner: daniel
# {'mark': 16, 'daniel': 9} , Winner: mark
# {'mark': 17, 'daniel': 8} , Winner: mark
# {'mark': 15, 'daniel': 10} , Winner: mark
# {'mark': 12, 'daniel': 13} , Winner: daniel
# {'mark': 13, 'daniel': 12} , Winner: mark
# {'mark': 15, 'daniel': 10} , Winner: mark
# {'mark': 13, 'daniel': 12} , Winner: mark
# {'mark': 13, 'daniel': 12} , Winner: mark
# {'dominique': 15, 'mees': 10} , Winner: dominique
# {'dominique': 15, 'mees': 10} , Winner: dominique
# {'dominique': 4, 'mees': 21} , Winner: mees
# {'dominique': 4, 'mees': 21} , Winner: mees
# {'dominique': 8, 'mees': 17} , Winner: mees
# {'dominique': 12, 'mees': 13} , Winner: mees
# {'dominique': 7, 'mees': 18} , Winner: mees
# {'dominique': 5, 'mees': 20} , Winner: mees
# {'dominique': 9, 'mees': 16} , Winner: mees
# {'dominique': 3, 'mees': 22} , Winner: mees
# {'dominique': 25, 'mees': 0} , Winner: dominique
# {'dominique': 7, 'daniel': 18} , Winner: daniel
# {'dominique': 9, 'daniel': 16} , Winner: daniel
# {'dominique': 9, 'daniel': 16} , Winner: daniel
# {'dominique': 14, 'daniel': 11} , Winner: dominique
# {'dominique': 10, 'daniel': 15} , Winner: daniel
# {'dominique': 15, 'daniel': 10} , Winner: dominique
# {'dominique': 9, 'daniel': 16} , Winner: daniel
# {'dominique': 6, 'daniel': 19} , Winner: daniel
# {'dominique': 6, 'daniel': 19} , Winner: daniel
# {'dominique': 10, 'daniel': 15} , Winner: daniel
# {'dominique': 10, 'daniel': 15} , Winner: daniel
# {'mees': 15, 'daniel': 10} , Winner: mees
# {'mees': 15, 'daniel': 10} , Winner: mees
# {'mees': 9, 'daniel': 16} , Winner: daniel
# {'mees': 8, 'daniel': 17} , Winner: daniel
# {'mees': 11, 'daniel': 14} , Winner: daniel
# {'mees': 14, 'daniel': 11} , Winner: mees
# {'mees': 11, 'daniel': 14} , Winner: daniel
# {'mees': 14, 'daniel': 11} , Winner: mees
# {'mees': 10, 'daniel': 15} , Winner: daniel
# {'mees': 18, 'daniel': 7} , Winner: mees
# {'mees': 17, 'daniel': 8} , Winner: mees
# Scores: mark: 40, ivo: 26, daniel: 21, mees: 17, dominique: 6
# Global scores:
# ivo: 9
# mark: 8
# mees: 7
# daniel: 7
# dominique: 5

# %% [markdown]
# ## Rock Paper Scissors Gun Duck

# %%
scores = get_zero_scores(init_all_players())

player_classes = get_all_player_classes()

for player1_class, player2_class in combinations(player_classes, 2):
    for i in range(5):
        player1 = player1_class()
        player2 = player2_class()

        rps_gun = RPS_Gun(player1, player2, render=False)
        winner = rps_gun.play_game()

        print(rps_gun.scores, f", Winner: {winner}")

        if winner == "tie":
            continue

        scores[winner] += 1

print_ordered_scores(scores)

update_global_scores(scores)
# Out:
# {'ivo': 24956, 'mark': 4000} , Winner: ivo
# {'ivo': 86087, 'mark': -47606681219543484454} , Winner: ivo
# {'ivo': 27089, 'mark': 7390} , Winner: ivo
# {'ivo': 82987, 'mark': -7352027673891772082} , Winner: ivo
# {'ivo': 82358, 'mark': -3500717442202292636} , Winner: ivo
# {'ivo': 53900, 'dominique': -412209996478} , Winner: ivo
# {'ivo': 80900, 'dominique': -496635441879910770} , Winner: ivo
# {'ivo': 61300, 'dominique': -12217067486984} , Winner: ivo
# {'ivo': 74800, 'dominique': -26465883152725714} , Winner: ivo
# {'ivo': 66809, 'dominique': -516553361118600} , Winner: ivo
# {'ivo': -3, 'mees': 3207184465} , Winner: mees
# {'ivo': 2175, 'mees': 24656103} , Winner: mees
# {'ivo': -124035960, 'mees': 12717922141} , Winner: mees
# {'ivo': 64, 'mees': 110145770} , Winner: mees
# {'ivo': -144, 'mees': 2511347872} , Winner: mees
# {'ivo': -10612375758712927, 'daniel': 11401112641699} , Winner: daniel
# {'ivo': -197528400849480, 'daniel': 27321572872143} , Winner: daniel
# {'ivo': -14508771, 'daniel': 367914392119} , Winner: daniel
# {'ivo': -795537309538, 'daniel': 3695091354154} , Winner: daniel
# {'ivo': -1628139, 'daniel': 116954343190} , Winner: daniel
# {'mark': -111402037903, 'dominique': 31887366} , Winner: dominique
# {'mark': 16889, 'dominique': 96148} , Winner: dominique
# {'mark': 15489, 'dominique': 1189778} , Winner: dominique
# {'mark': 20800, 'dominique': 60197} , Winner: dominique
# {'mark': -8887686552694222333, 'dominique': 6036186444} , Winner: dominique
# {'mark': -1716605546162508, 'mees': 4412858022} , Winner: mees
# {'mark': -4502882555108285140, 'mees': 38066487009} , Winner: mees
# {'mark': -5167752242462615701, 'mees': 5217332279} , Winner: mees
# {'mark': -20499862673781, 'mees': 4376598433} , Winner: mees
# {'mark': -10564, 'mees': 13336834} , Winner: mees
# {'mark': -1643356964288139796, 'daniel': 2929857097684464} , Winner: daniel
# {'mark': -417622011, 'daniel': 714949743} , Winner: daniel
# {'mark': 12375, 'daniel': 11290} , Winner: mark
# {'mark': -9738796626, 'daniel': 19320869778} , Winner: daniel
# {'mark': -10419378142155020634, 'daniel': 494644860555168} , Winner: daniel
# {'dominique': 10920, 'mees': 439257} , Winner: mees
# {'dominique': 12444, 'mees': 348516} , Winner: mees
# {'dominique': 10480, 'mees': 4197892} , Winner: mees
# {'dominique': 9032, 'mees': 205973} , Winner: mees
# {'dominique': 11680, 'mees': 272502} , Winner: mees
# {'dominique': 5296676576991093166793275976025693, 'daniel': -358095749304406} , Winner: dominique
# {'dominique': -26236, 'daniel': 393687} , Winner: daniel
# {'dominique': -8698878851363707, 'daniel': 570554646456973516267} , Winner: daniel
# {'dominique': -5302, 'daniel': 71041} , Winner: daniel
# {'dominique': 4015, 'daniel': -465} , Winner: dominique
# {'mees': 24734283781969390184264399395, 'daniel': -552} , Winner: mees
# {'mees': 3155326516613315282355013226372645, 'daniel': -17303608307880} , Winner: mees
# {'mees': 152946611910893362446867393214104, 'daniel': -281} , Winner: mees
# {'mees': 5219750446288409853392827049225791613659083, 'daniel': -3383284563773413} , Winner: mees
# {'mees': 1067840073620276805125629100184, 'daniel': -442} , Winner: mees
# Scores: mees: 20, daniel: 12, ivo: 10, dominique: 7, mark: 1
# Global scores:
# ivo: 11
# mees: 11
# daniel: 10
# mark: 8
# dominique: 6

# %%
print_global_scores()
# Out:
# Global scores:
# ivo: 11
# mees: 11
# daniel: 10
# mark: 8
# dominique: 6
