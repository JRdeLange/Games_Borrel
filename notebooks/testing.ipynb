# %% [markdown]
# Here you can test your stuff.
#
# For each of the games I have preset:
# - A single game with rendering/printing enabled so you can see what's going on
# - A competition length game against the dummy player to benchmark your performance
#     - Please keep the runtime of this cell (when competing against dummy) under like ~45 seconds.
#
# After the first scoring round you can (and probably should!) test your policies against the other players!

# %% [markdown]
# Players

# %%
from borrel.policies.dummy import Dummy
from borrel.policies.ivo import Ivo
from borrel.policies.jakko import Jakko
from borrel.policies.mark import Mark
from borrel.policies.allia import Allia
from borrel.policies.dominique import Dominique
from borrel.policies.dirk import Dirk
from borrel.policies.mees import Mees

from borrel.games.tron import Tron
from borrel.games.sorry import Sorry
from borrel.games.dots_and_lines import DotsAndLines
from borrel.games.rps_gun import RPS_Gun

you_class = Mark # Change this to your class :)

# %% [markdown]
# ## Tron

# %% [markdown]
# Single game

# %%
# Note - you start as the left player ("-"). Switch the order of players to play as the right player ("|").

you = you_class()
opponent = Dummy()

tron = Tron([you, opponent], render=True)
winner = tron.play_game()

print(f"Winner: {winner}")
print("Final grid:")
tron.renderer.render()
# Out:
# +++++++++++++++++
# +               +
# +               +
# +               +
# +     >   <     +
# +               +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +               +
# +         ^     +
# +     - > |     +
# +               +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +         ^     +
# +         |     +
# +     - - |     +
# +       v       +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +         | >   +
# +         |     +
# +     - - |     +
# +       - >     +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +         | | > +
# +         |     +
# +     - - |     +
# +       - - >   +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +         | | | +
# +         |   v +
# +     - - |     +
# +       - - - > +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +         | | | +
# +         |   | +
# +     - - |   v +
# +       - - - - +
# +               +
# +               +
# +++++++++++++++++
# Winner: dummy
# Final grid:
# +++++++++++++++++
# +               +
# +         | | | +
# +         |   | +
# +     - - |   v +
# +       - - - - +
# +               +
# +               +
# +++++++++++++++++

# %% [markdown]
# Benchmark

# %%
you = you_class()
opponent = Dummy()
score = {you.name: 0, opponent.name: 0}

for i in range(11):
    you = you_class()
    opponent = Dummy()

    tron = Tron([you, opponent], render=False)
    winner = tron.play_game()
    if winner == "tie":
        continue
    score[winner] += 1

print(f"Scores: {score}")
# Out:
# Scores: {'mark': 6, 'dummy': 5}

# %% [markdown]
# ## Rock Paper Scissors Gun Duck

# %% [markdown]
# Single game

# %%
you = you_class()
opponent = Dummy()

rps_gun = RPS_Gun(you, opponent, render=True)

winner = rps_gun.play_game(rounds=5)
print(f"Final scores: {rps_gun.scores}")
rps_gun.history
# Out:
# Round 1: mark (r) vs dummy (p)
# mark bet: 100, dummy bet: 100
# mark score: -110, dummy score: 200
# mark reload timer: 4, dummy reload timer: 4
# Round result: dummy gets 100 points
#
# mark tried to shoot but is reloading!
# Round 2: mark (g) vs dummy (r)
# mark bet: 100, dummy bet: 100
# mark score: -231, dummy score: 400
# mark reload timer: 3, dummy reload timer: 3
# Round result: dummy gets 100 points
#
# mark tried to shoot but is reloading!
# Round 3: mark (g) vs dummy (s)
# mark bet: 100, dummy bet: 100
# mark score: -364, dummy score: 600
# mark reload timer: 2, dummy reload timer: 2
# Round result: dummy gets 100 points
#
# Round 4: mark (p) vs dummy (d)
# mark bet: 100, dummy bet: 100
# mark score: -180, dummy score: 500
# mark reload timer: 1, dummy reload timer: 1
# Round result: mark gets 100 points
#
# Round 5: mark (s) vs dummy (s)
# mark bet: 100, dummy bet: 100
# mark score: -198, dummy score: 500
# mark reload timer: 0, dummy reload timer: 0
# Round result: tie
#
# Final scores: {'mark': -198, 'dummy': 500}
#   mark dummy mark_score dummy_score mark_reload_timer dummy_reload_timer  \
# 0    r     p       -100         200                 4                  4
# 1    g     r       -210         400                 3                  3
# 2    g     s       -331         600                 2                  2
# 3    p     d       -164         500                 1                  1
# 4    s     s       -180         500                 0                  0
#
#   rounds_remaining  mark_bet  dummy_bet
# 0                4     100.0      100.0
# 1                3     100.0      100.0
# 2                2     100.0      100.0
# 3                1     100.0      100.0
# 4                0     100.0      100.0

# %% [markdown]
# Benchmark

# %%
you = you_class()
opponent = Dummy()

scores = {you.name: 0, opponent.name: 0}

for i in range(7):
    you = you_class()
    opponent = Dummy()

    rps_gun = RPS_Gun(you, opponent, render=False)
    winner = rps_gun.play_game()
    if winner == "tie":
        continue
    scores[winner] += 1
    print(rps_gun.scores, f"winner: {winner}")

print(f"Scores: {scores}")
# Out:
# {'mark': 15800, 'dummy': 17289} winner: dummy
# {'mark': 14700, 'dummy': 18516} winner: dummy
# {'mark': 20990, 'dummy': 13434} winner: mark
# {'mark': 66400, 'dummy': -746761410052487938} winner: mark
# {'mark': 11190, 'dummy': 21690} winner: dummy
# {'mark': 17366, 'dummy': 14700} winner: mark
# {'mark': -6503103755541820863, 'dummy': 71600} winner: dummy
# Scores: {'mark': 3, 'dummy': 4}

# %% [markdown]
# ## Dots and Lines

# %% [markdown]
# Single game

# %%
# Init players
player1 = you_class()
player2 = Dummy()

dots_and_lines = DotsAndLines(player1, player2, size=3, render=True)
winner = dots_and_lines.play_game()

print("Winner:", winner)
print("Scores:", dots_and_lines.scores)
print("Turns:", len(dots_and_lines.history))
# Out:
# Starting player: mark
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('h', 0, 1), completed 0 box(es)
# .   .---.   .
#
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
# Scores: mark=0 | dummy=0
# dummy plays ('h', 0, 2), completed 0 box(es)
# .   .---.---.
#
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('h', 1, 2), completed 0 box(es)
# .   .---.---.
#
# .   .   .---.
#
# .   .   .   .
#
# .   .   .   .
# Scores: mark=0 | dummy=0
# dummy plays ('v', 2, 0), completed 0 box(es)
# .   .---.---.
#
# .   .   .---.
#
# .   .   .   .
# |
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('v', 2, 3), completed 0 box(es)
# .   .---.---.
#
# .   .   .---.
#
# .   .   .   .
# |           |
# .   .   .   .
# Scores: mark=0 | dummy=0
# dummy plays ('v', 2, 1), completed 0 box(es)
# .   .---.---.
#
# .   .   .---.
#
# .   .   .   .
# |   |       |
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('v', 0, 3), completed 0 box(es)
# .   .---.---.
#             |
# .   .   .---.
#
# .   .   .   .
# |   |       |
# .   .   .   .
# Scores: mark=0 | dummy=0
# dummy plays ('h', 2, 0), completed 0 box(es)
# .   .---.---.
#             |
# .   .   .---.
#
# .---.   .   .
# |   |       |
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('v', 0, 1), completed 0 box(es)
# .   .---.---.
#     |       |
# .   .   .---.
#
# .---.   .   .
# |   |       |
# .   .   .   .
# Scores: mark=0 | dummy=0
# dummy plays ('v', 0, 0), completed 0 box(es)
# .   .---.---.
# |   |       |
# .   .   .---.
#
# .---.   .   .
# |   |       |
# .   .   .   .
# Scores: mark=0 | dummy=0
# mark plays ('v', 0, 2), completed 1 box(es)
# .   .---.---.
# |   |   | M |
# .   .   .---.
#
# .---.   .   .
# |   |       |
# .   .   .   .
# Scores: mark=1 | dummy=0
# mark plays ('v', 1, 3), completed 0 box(es)
# .   .---.---.
# |   |   | M |
# .   .   .---.
#             |
# .---.   .   .
# |   |       |
# .   .   .   .
# Scores: mark=1 | dummy=0
# dummy plays ('h', 3, 0), completed 1 box(es)
# .   .---.---.
# |   |   | M |
# .   .   .---.
#             |
# .---.   .   .
# | D |       |
# .---.   .   .
# Scores: mark=1 | dummy=1
# dummy plays ('h', 0, 0), completed 0 box(es)
# .---.---.---.
# |   |   | M |
# .   .   .---.
#             |
# .---.   .   .
# | D |       |
# .---.   .   .
# Scores: mark=1 | dummy=1
# mark plays ('h', 1, 0), completed 1 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
#             |
# .---.   .   .
# | D |       |
# .---.   .   .
# Scores: mark=2 | dummy=1
# mark plays ('v', 1, 0), completed 0 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |           |
# .---.   .   .
# | D |       |
# .---.   .   .
# Scores: mark=2 | dummy=1
# dummy plays ('v', 1, 2), completed 0 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |       |   |
# .---.   .   .
# | D |       |
# .---.   .   .
# Scores: mark=2 | dummy=1
# mark plays ('v', 2, 2), completed 0 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |       |   |
# .---.   .   .
# | D |   |   |
# .---.   .   .
# Scores: mark=2 | dummy=1
# dummy plays ('h', 3, 1), completed 0 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |       |   |
# .---.   .   .
# | D |   |   |
# .---.---.   .
# Scores: mark=2 | dummy=1
# mark plays ('h', 2, 2), completed 1 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |       | M |
# .---.   .---.
# | D |   |   |
# .---.---.   .
# Scores: mark=3 | dummy=1
# mark plays ('h', 3, 2), completed 1 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# |       | M |
# .---.   .---.
# | D |   | M |
# .---.---.---.
# Scores: mark=4 | dummy=1
# mark plays ('v', 1, 1), completed 1 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# | M |   | M |
# .---.   .---.
# | D |   | M |
# .---.---.---.
# Scores: mark=5 | dummy=1
# mark plays ('h', 2, 1), completed 1 box(es)
# .---.---.---.
# | M |   | M |
# .---.   .---.
# | M |   | M |
# .---.---.---.
# | D | M | M |
# .---.---.---.
# Scores: mark=6 | dummy=1
# mark plays ('h', 1, 1), completed 2 box(es)
# .---.---.---.
# | M | M | M |
# .---.---.---.
# | M | M | M |
# .---.---.---.
# | D | M | M |
# .---.---.---.
# Scores: mark=8 | dummy=1
# Winner: mark
# Scores: {'mark': 8, 'dummy': 1}
# Turns: 24

# %% [markdown]
# Competition-length benchmark vs dummy

# %%
wins = {"Dummy_1": 0, "Dummy_2": 0, "tie": 0}

for _ in range(100):
    player1 = Dummy("Dummy_1")
    player2 = Dummy("Dummy_2")

    dots_and_lines = DotsAndLines(player1, player2, size=5, render=False)
    winner = dots_and_lines.play_game()
    wins[winner] += 1

wins
# Out:
# {'Dummy_1': 47, 'Dummy_2': 53, 'tie': 0}

# %% [markdown]
# ## Sorry

# %% [markdown]
# Single game

# %%
# Init players
players = [
    you_class(),
    Dummy("Dummy_2"),
    Dummy("Dummy_3"),
    Dummy("Dummy_4"),
]

sorry = Sorry(players, render=True)

sorry.play_game()
# Out:
# Turn of Dummy_3, dice roll: 2
#        home space
# 0   Dummy_3  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# 5   Dummy_4  None
# 6      None  None
# 7      None  None
# 8      None  None
# 9      None  None
# 10     mark  None
# 11     None  None
# 12     None  None
# 13     None  None
# 14     None  None
# 15  Dummy_2  None
# 16     None  None
# 17     None  None
# 18     None  None
# 19     None  None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [1, 2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 6
#        home space
# 0   Dummy_3  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# 5   Dummy_4  None
# 6      None  None
# 7      None  None
# 8      None  None
# 9      None  None
# 10     mark  None
# 11     None  None
# 12     None  None
# 13     None  None
# 14     None  None
# 15  Dummy_2  None
# 16     None  None
# 17     None  None
# 18     None  None
# 19     None  None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [1, 2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_4_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_4_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_4_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_4_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None  Dummy_4_1
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None  Dummy_4_1
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_2_1
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None  Dummy_4_1
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_2_1
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None  Dummy_4_1
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_2_1
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_2_1
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_1
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_4_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [1, 2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_4_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_4_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_4_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_4_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_4_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None     mark_1
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 5
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_4_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None     mark_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_4_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None     mark_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 1
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None     mark_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 4
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None     mark_1
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None     mark_1
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None     mark_1
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None  Dummy_4_1
# 12     None       None
# 13     None     mark_1
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None  Dummy_4_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None     mark_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_2_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None  Dummy_4_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None     mark_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_2_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None  Dummy_4_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None     mark_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_2_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_4_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None  Dummy_2_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_4_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_4_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_4_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 4
#        home      space
# 0   Dummy_3  Dummy_4_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 2
#        home      space
# 0   Dummy_3  Dummy_4_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_2_1
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 6
#        home      space
# 0   Dummy_3  Dummy_4_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_2_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3  Dummy_4_1
# 1      None  Dummy_3_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_2_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_1
# 2      None  Dummy_4_1
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_2_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_1
# 2      None  Dummy_4_1
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None  Dummy_2_1
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_1
# 2      None  Dummy_4_1
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_2_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_4_1
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_3_1
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_2_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_3_1
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_2_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4  Dummy_3_1
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_2_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4  Dummy_3_1
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None  Dummy_4_1
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None  Dummy_3_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_1
# 9      None       None
# 10     mark       None
# 11     None  Dummy_3_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 4
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_1
# 9      None       None
# 10     mark       None
# 11     None  Dummy_3_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_2_1
# 9      None       None
# 10     mark       None
# 11     None  Dummy_3_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_2_1
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_3_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_2_1
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_3_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_2_1
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_3_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None  Dummy_3_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_3_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None     mark_1
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None  Dummy_3_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None  Dummy_2_1
# 15  Dummy_2       None
# 16     None       None
# 17     None     mark_1
# 18     None  Dummy_3_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 2
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None     mark_1
# 18     None  Dummy_3_1
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 3
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None     mark_1
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 6
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None     mark_1
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1], 'Dummy_4': []}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 3
#        home      space
# 0   Dummy_3  Dummy_2_1
# 1      None       None
# 2      None       None
# 3      None     mark_1
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1], 'Dummy_4': []}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None  Dummy_2_1
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1], 'Dummy_4': []}
# Dummy_3 decides to move piece 2
# Turn of Dummy_4, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None  Dummy_2_1
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4, 1], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [2, 3, 4], 'Dummy_4': [2, 3, 4, 1]}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None  Dummy_2_1
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# ...
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_4_4
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_3_3
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_4_4
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_3_3
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_4_4
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_3_3
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_3 decides to move piece 3
# Turn of Dummy_4, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_4_4
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_3_3
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_4
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_3_3
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_4
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_3_3
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_4
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None  Dummy_3_3
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_3 decides to move piece 3
# Turn of Dummy_4, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_3_3
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None  Dummy_4_4
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_3_3
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_4_4
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_3_3
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_4_4
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None  Dummy_2_1
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None  Dummy_3_3
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_4_4
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_3 decides to move piece 3
# Turn of Dummy_4, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_3_3
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark  Dummy_4_4
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_3_3
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_4_4
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_3_3
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_4_4
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_2_1
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_4_4
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4, 3], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_3 decides to move piece 3
# Turn of Dummy_4, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None  Dummy_4_4
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4, 3], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_4
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4, 3], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 3
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None  Dummy_2_1
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_4
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4, 3], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_2 decides to move piece 1
# Turn of Dummy_3, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None       None
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None  Dummy_2_1
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_4
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4, 3], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_3 decides to move piece 3
# Turn of Dummy_4, dice roll: 6
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_3
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None  Dummy_2_1
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None  Dummy_4_4
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3]}
# Dummy_4 decides to move piece 4
# Turn of mark, dice roll: 5
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_3
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None  Dummy_2_1
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3, 4]}
# mark decides to move piece 1
# Turn of Dummy_2, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_3
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None  Dummy_2_1
# 8      None       None
# 9      None       None
# 10     mark       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'mark': [2, 3, 4], 'Dummy_2': [2, 3, 4, 1], 'Dummy_3': [4], 'Dummy_4': []}
# pieces finished: {'mark': [], 'Dummy_2': [], 'Dummy_3': [1, 2], 'Dummy_4': [1, 2, 3, 4]}
# Dummy_2 decides to move piece 1
# ['Dummy_4']

# %% [markdown]
# Benchmark

# %%
player_classes = [you_class, Dummy, Dummy, Dummy]

for i in range(11):
    sorry = Sorry(players=[player() for player in player_classes], render=False)
    winners = sorry.play_game()

    print(f"Winner(s): {winners}")
# Out:
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['mark']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
