# %% [markdown]
# Here you can test your stuff.
#
# For each of the games I have preset:
# - A single game with rendering/printing enabled so you can see what's going on
# - A competition length game against the dummy player to benchmark your performance
#     - Please keep the runtime of this cell (when competing against dummy) under like ~45 seconds.
#
# After the first scoring round you can (and probably should!) test your policies against the other players!

# %% [markdown]
# Players

# %%
from borrel.policies.dummy import Dummy
from borrel.policies.ivo import Ivo
from borrel.policies.jakko import Jakko
from borrel.policies.mark import Mark
from borrel.policies.allia import Allia
from borrel.policies.dominique import Dominique
from borrel.policies.dirk import Dirk
from borrel.policies.mees import Mees
from borrel.policies.daniel import Daniel

from borrel.games.tron import Tron
from borrel.games.sorry import Sorry
from borrel.games.dots_and_lines import DotsAndLines
from borrel.games.rps_gun import RPS_Gun

you_class = Daniel # Change this to your class :)

# %% [markdown]
# ## Tron

# %% [markdown]
# Single game

# %%
# Note - you start as the left player ("-"). Switch the order of players to play as the right player ("|").

you = you_class()
opponent = Dummy()

tron = Tron([you, opponent], render=True)
winner = tron.play_game()

print(f"Winner: {winner}")
print("Final grid:")
tron.renderer.render()
# Out:
# +++++++++++++++++
# +               +
# +               +
# +               +
# +     >   <     +
# +               +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +               +
# +     ^         +
# +     -   |     +
# +         v     +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +               +
# +     ^         +
# +     -         +
# +     -   |     +
# +       < |     +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +     ^         +
# +     -         +
# +     -         +
# +     -   |     +
# +     < | |     +
# +               +
# +               +
# +++++++++++++++++
# +++++++++++++++++
# +   < -         +
# +     -         +
# +     -         +
# +     X   |     +
# +     | | |     +
# +               +
# +               +
# +++++++++++++++++
# Winner: daniel
# Final grid:
# +++++++++++++++++
# +   < -         +
# +     -         +
# +     -         +
# +     X   |     +
# +     | | |     +
# +               +
# +               +
# +++++++++++++++++

# %% [markdown]
# Benchmark

# %%
you = you_class()
opponent = Dummy()
score = {you.name: 0, opponent.name: 0}

for i in range(11):
    you = you_class()
    opponent = Dummy()

    tron = Tron([you, opponent], render=False)
    winner = tron.play_game()
    if winner == "tie":
        continue
    score[winner] += 1

print(f"Scores: {score}")
# Out:
# Scores: {'daniel': 11, 'dummy': 0}

# %% [markdown]
# ## Rock Paper Scissors Gun Duck

# %% [markdown]
# Single game

# %%
you = you_class()
opponent = Dummy()

rps_gun = RPS_Gun(you, opponent, render=True)

winner = rps_gun.play_game(rounds=5)
print(f"Final scores: {rps_gun.scores}")
rps_gun.history
# Out:
# Round 1: daniel (d) vs dummy (s)
# daniel bet: 100, dummy bet: 100
# daniel score: -110, dummy score: 200
# daniel reload timer: 4, dummy reload timer: 4
# Round result: dummy gets 100 points
#
# Round 2: daniel (d) vs dummy (r)
# daniel bet: 100, dummy bet: 100
# daniel score: 90, dummy score: 100
# daniel reload timer: 3, dummy reload timer: 3
# Round result: daniel gets 100 points
#
# dummy tried to shoot but is reloading!
# Round 3: daniel (p) vs dummy (g)
# daniel bet: 100, dummy bet: 100
# daniel score: 290, dummy score: 0
# daniel reload timer: 2, dummy reload timer: 2
# Round result: daniel gets 100 points
#
# Round 4: daniel (s) vs dummy (d)
# daniel bet: 100, dummy bet: 100
# daniel score: 490, dummy score: -110
# daniel reload timer: 1, dummy reload timer: 1
# Round result: daniel gets 100 points
#
# Round 5: daniel (r) vs dummy (g)
# daniel bet: 100, dummy bet: 100
# daniel score: 690, dummy score: -231
# daniel reload timer: 0, dummy reload timer: 5
# Round result: daniel gets 100 points
#
# Final scores: {'daniel': 690, 'dummy': -231}
#   daniel dummy daniel_score dummy_score daniel_reload_timer  \
# 0      d     s         -100         200                   4
# 1      d     r           90         100                   3
# 2      p     g          290           0                   2
# 3      s     d          490        -100                   1
# 4      r     g          690        -210                   0
#
#   dummy_reload_timer rounds_remaining  daniel_bet  dummy_bet
# 0                  4                4       100.0      100.0
# 1                  3                3       100.0      100.0
# 2                  2                2       100.0      100.0
# 3                  1                1       100.0      100.0
# 4                  0                0       100.0      100.0

# %% [markdown]
# Benchmark

# %%
you = you_class()
opponent = Dummy()

scores = {you.name: 0, opponent.name: 0}

for i in range(7):
    you = you_class()
    opponent = Dummy()

    rps_gun = RPS_Gun(you, opponent, render=False)
    winner = rps_gun.play_game()
    if winner == "tie":
        continue
    scores[winner] += 1
    print(rps_gun.scores, f"winner: {winner}")

print(f"Scores: {scores}")
# Out:
# {'daniel': 23800, 'dummy': 9689} winner: daniel
# {'daniel': 25790, 'dummy': 9000} winner: daniel
# {'daniel': -13281877089210291601, 'dummy': 68100} winner: dummy
# {'daniel': 21700, 'dummy': 11788} winner: daniel
# {'daniel': 22053, 'dummy': 10400} winner: daniel
# {'daniel': 24577, 'dummy': 9577} winner: daniel
# {'daniel': 22700, 'dummy': 9368} winner: daniel
# Scores: {'daniel': 6, 'dummy': 1}

# %% [markdown]
# ## Dots and Lines

# %% [markdown]
# Single game

# %%
# Init players
player1 = you_class()
player2 = Dummy(name="loser")

dots_and_lines = DotsAndLines(player1, player2, size=3, render=True)
winner = dots_and_lines.play_game()

print("Winner:", winner)
print("Scores:", dots_and_lines.scores)
print("Turns:", len(dots_and_lines.history))
# Out:
# Starting player: loser
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('v', 2, 0), completed 0 box(es)
# .   .   .   .
#
# .   .   .   .
#
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('v', 1, 0), completed 0 box(es)
# .   .   .   .
#
# .   .   .   .
# |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('v', 1, 1), completed 0 box(es)
# .   .   .   .
#
# .   .   .   .
# |   |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('v', 1, 3), completed 0 box(es)
# .   .   .   .
#
# .   .   .   .
# |   |       |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('v', 0, 1), completed 0 box(es)
# .   .   .   .
#     |
# .   .   .   .
# |   |       |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('h', 1, 2), completed 0 box(es)
# .   .   .   .
#     |
# .   .   .---.
# |   |       |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('v', 0, 3), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .   .---.
# |   |       |
# .   .   .   .
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('h', 2, 2), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .   .---.
# |   |       |
# .   .   .---.
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('h', 1, 1), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .---.---.
# |   |       |
# .   .   .---.
# |
# .   .   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('v', 2, 1), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .---.---.
# |   |       |
# .   .   .---.
# |   |
# .   .   .   .
# Scores: daniel=0 | loser=0
# loser plays ('h', 3, 0), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .---.---.
# |   |       |
# .   .   .---.
# |   |
# .---.   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('h', 2, 1), completed 0 box(es)
# .   .   .   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |
# .---.   .   .
# Scores: daniel=0 | loser=0
# loser plays ('h', 0, 1), completed 0 box(es)
# .   .---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |
# .---.   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('v', 2, 3), completed 0 box(es)
# .   .---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |       |
# .---.   .   .
# Scores: daniel=0 | loser=0
# loser plays ('h', 0, 0), completed 0 box(es)
# .---.---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |       |
# .---.   .   .
# Scores: daniel=0 | loser=0
# daniel plays ('h', 3, 2), completed 0 box(es)
# .---.---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |       |
# .---.   .---.
# Scores: daniel=0 | loser=0
# loser plays ('h', 3, 1), completed 0 box(es)
# .---.---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   |       |
# .---.---.---.
# Scores: daniel=0 | loser=0
# daniel plays ('v', 2, 2), completed 2 box(es)
# .---.---.   .
#     |       |
# .   .---.---.
# |   |       |
# .   .---.---.
# |   | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=0
# daniel plays ('h', 1, 0), completed 0 box(es)
# .---.---.   .
#     |       |
# .---.---.---.
# |   |       |
# .   .---.---.
# |   | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=0
# loser plays ('v', 1, 2), completed 2 box(es)
# .---.---.   .
#     |       |
# .---.---.---.
# |   | L | L |
# .   .---.---.
# |   | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=2
# loser plays ('h', 2, 0), completed 2 box(es)
# .---.---.   .
#     |       |
# .---.---.---.
# | L | L | L |
# .---.---.---.
# | L | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=4
# loser plays ('v', 0, 0), completed 1 box(es)
# .---.---.   .
# | L |       |
# .---.---.---.
# | L | L | L |
# .---.---.---.
# | L | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=5
# loser plays ('v', 0, 2), completed 1 box(es)
# .---.---.   .
# | L | L |   |
# .---.---.---.
# | L | L | L |
# .---.---.---.
# | L | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=6
# loser plays ('h', 0, 2), completed 1 box(es)
# .---.---.---.
# | L | L | L |
# .---.---.---.
# | L | L | L |
# .---.---.---.
# | L | D | D |
# .---.---.---.
# Scores: daniel=2 | loser=7
# Winner: loser
# Scores: {'daniel': 2, 'loser': 7}
# Turns: 24

# %% [markdown]
# Competition-length benchmark vs dummy

# %%
wins = {"Dummy_1": 0, "Dummy_2": 0, "tie": 0}

for _ in range(100):
    player1 = Dummy("Dummy_1")
    player2 = Dummy("Dummy_2")

    dots_and_lines = DotsAndLines(player1, player2, size=5, render=False)
    winner = dots_and_lines.play_game()
    wins[winner] += 1

wins
# Out:
# {'Dummy_1': 50, 'Dummy_2': 50, 'tie': 0}

# %% [markdown]
# ## Sorry

# %% [markdown]
# Single game

# %%
# Init players
players = [
    you_class(),
    Dummy("Dummy_2"),
    Dummy("Dummy_3"),
    Dummy("Dummy_4"),
]

sorry = Sorry(players, render=True)

sorry.play_game()
# Out:
# Turn of Dummy_3, dice roll: 6
#        home space
# 0   Dummy_3  None
# 1      None  None
# 2      None  None
# 3      None  None
# 4      None  None
# 5   Dummy_4  None
# 6      None  None
# 7      None  None
# 8      None  None
# 9      None  None
# 10   daniel  None
# 11     None  None
# 12     None  None
# 13     None  None
# 14     None  None
# 15  Dummy_2  None
# 16     None  None
# 17     None  None
# 18     None  None
# 19     None  None
# pieces at home: {'daniel': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [1, 2, 3, 4], 'Dummy_4': [1, 2, 3, 4]}
# pieces finished: {'daniel': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_3 decides to move piece 1
# Turn of Dummy_4, dice roll: 1
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10   daniel       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'daniel': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [1, 2, 3, 4]}
# pieces finished: {'daniel': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# Dummy_4 decides to move piece 1
# Turn of daniel, dice roll: 2
#        home      space
# 0   Dummy_3       None
# 1      None  Dummy_3_1
# 2      None       None
# 3      None       None
# 4      None       None
# 5   Dummy_4       None
# 6      None       None
# 7      None       None
# 8      None       None
# 9      None       None
# 10   daniel       None
# 11     None       None
# 12     None       None
# 13     None       None
# 14     None       None
# 15  Dummy_2       None
# 16     None       None
# 17     None       None
# 18     None       None
# 19     None       None
# pieces at home: {'daniel': [1, 2, 3, 4], 'Dummy_2': [1, 2, 3, 4], 'Dummy_3': [2, 3, 4], 'Dummy_4': [1, 2, 3, 4]}
# pieces finished: {'daniel': [], 'Dummy_2': [], 'Dummy_3': [], 'Dummy_4': []}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 11
#       7 ]
#       8
#       9 sorry = Sorry(players, render=True)
#      10
# ---> 11 sorry.play_game()
#
# File ~/Games_Borrel/borrel/games/sorry.py:138, in Sorry.play_game(self)
#     135 self.reset()
#     137 while True:
# --> 138     self.play_turn()
#     139     for player in self.players:
#     140         if len(self.info["pieces_finished"][player.name]) == 4:
#
# File ~/Games_Borrel/borrel/games/sorry.py:71, in Sorry.play_turn(self)
#      68 if self.render:
#      69     self.render_state(dice_roll, player.name)
# ---> 71 move = player.sorry(
#      72     copy.deepcopy(self.board), copy.deepcopy(self.info), dice_roll
#      73 )
#      75 if self.render:
#      76     print(f"{player.name} decides to move piece {move}")
#
# File ~/Games_Borrel/borrel/policies/daniel.py:478, in Daniel.sorry(self, board, info, dice_roll)
#     475         target_position = (current_position + dice_roll) % board_size
#     477 # Check if target position has an opponent piece
# --> 478 target_space = board.loc[target_position, "space"]
#     479 # If there's an opponent piece at target, capture it!
#     480 if pd.notna(target_space) and not str(target_space).startswith(f"{self.name}_"):
#
# File ~/Games_Borrel/.venv/lib/python3.13/site-packages/pandas/core/indexing.py:1183, in _LocationIndexer.__getitem__(self, key)
#    1181     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#    1182     if self._is_scalar_access(key):
# -> 1183         return self.obj._get_value(*key, takeable=self._takeable)
#    1184     return self._getitem_tuple(key)
#    1185 else:
#    1186     # we by definition only have the 0th axis
#
# File ~/Games_Borrel/.venv/lib/python3.13/site-packages/pandas/core/frame.py:4221, in DataFrame._get_value(self, index, col, takeable)
#    4217         if not isinstance(self.index, MultiIndex):
#    4218             # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    4219             #  results if our categories are integers that dont match our codes
#    4220             # IntervalIndex: IntervalTree has no get_loc
# -> 4221             row = self.index.get_loc(index)
#    4222             return series._values[row]
#    4223
#    4224         # For MultiIndex going through engine effectively restricts us to
#
# File ~/Games_Borrel/.venv/lib/python3.13/site-packages/pandas/core/indexes/range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: None

# %% [markdown]
# Benchmark

# %%
player_classes = [you_class, Dummy, Dummy, Dummy]

for i in range(11):
    sorry = Sorry(players=[player() for player in player_classes], render=False)
    winners = sorry.play_game()

    print(f"Winner(s): {winners}")
# Out:
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
# Winner(s): ['dummy']
